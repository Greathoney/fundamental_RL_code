# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class WindyGrid:
    action_table = {0: np.array((0, 1)), 1: np.array((1, 0)), 2: np.array((0, -1)), 3: np.array((-1, 0)), 4: np.array((1, 1)), 5: np.array((1, -1)), 6: np.array((-1, -1)), 7: np.array((-1, 1))}

    def __init__(self):
        self.pos = (3, 0)
        self.wind = [0, 0, 0, 1, 1, 1, 2, 2, 1, 0]

    def reset(self):
        self.pos = (3, 0)
        return self.pos
    
    def step(self, action):
        new_pos = self.pos + self.action_table[action] - np.array([self.wind[self.pos[1]], 0])
        new_pos = np.clip(new_pos, [0, 0], [6, 9])

        reward = -1
        done = (new_pos == [3, 7]).all()
        self.pos = tuple(new_pos)

        return self.pos, reward, done

# %%
alpha = 0.5
epsilon = 0.1
gamma = 1

episodes = 200
cum_step = 0

# %%
Q = np.zeros((7, 10, 8))

# %%
def select_action(Q, state):
    if np.random.rand() < epsilon:
        return np.random.randint(8)
    else:
        return np.argmax(Q[state])

# %%
epi_step_log = []

for episode in range(episodes):
    env = WindyGrid()
    state = env.reset()
    action = select_action(Q, state)

    while True:
        next_state, reward, done = env.step(action)
        next_action = select_action(Q, next_state)

        Q[*state, action] += alpha * (reward + gamma * Q[*next_state, next_action] - Q[*state, action])
        state = next_state
        action = next_action
        
        cum_step += 1
        epi_step_log.append((cum_step, episode))

        if done:
            break

# %%
cum_step_np = np.array(epi_step_log)
plt.plot(cum_step_np[:, 0], cum_step_np[:, 1])
plt.xlabel('Time steps')
plt.ylabel('Episodes')
plt.show()

# %%
states = []
actions = []

env = WindyGrid()
state = env.reset()
states.append(state)
action = np.argmax(Q[state])
actions.append(action)

while True:
    next_state, reward, done = env.step(action)
    action = np.argmax(Q[next_state])

    state = next_state
    states.append(state)
    actions.append(action)

    if done:
        break

# %%
states_np = np.array(states)
plt.plot(states_np[:, 1], states_np[:, 0], 'o-')
plt.xticks(range(10))
plt.yticks(range(7))
plt.xlim(0, 9)
plt.ylim(6, 0)
plt.grid()
# plt axis equal
plt.gca().set_aspect('equal', adjustable='box')
for i in range(len(states_np)-1):
    plt.quiver(states_np[i, 1], states_np[i, 0], WindyGrid.action_table[actions[i]][1], WindyGrid.action_table[actions[i]][0], angles='xy', scale_units='xy', scale=2, color='r')
plt.show()
